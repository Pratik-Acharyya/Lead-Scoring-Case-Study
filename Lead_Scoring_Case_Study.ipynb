# %% [markdown]
# # Data Understanding

# %%
# Surpass the warnings
import warnings
warnings.filterwarnings("ignore")

# Import the modules
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Expand the display
pd.set_option('display.max_columns', 500)

# Model Building libraries
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Model Evalutaion
from sklearn import metrics

# %%
# Read the data
lead = pd.read_csv("/content/Leads.csv", sep=",", encoding="ISO-8859-1", header=0)
lead.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# 0                            0                   0.0  Page Visited on Website
# 1                          674                   2.5             Email Opened
# 2                         1532                   2.0             Email Opened
# 3                          305                   1.0              Unreachable
# 4                         1428                   1.0        Converted to Lead
#
#   Country           Specialization How did you hear about X Education  \
# 0     NaN                   Select                             Select
# 1   India                   Select                             Select
# 2   India  Business Administration                             Select
# 3   India    Media and Advertising                      Word Of Mouth
# 4   India                   Select                              Other
#
#   What is your current occupation  \
# 0                      Unemployed
# 1                      Unemployed
# 2                         Student
# 3                      Unemployed
# 4                      Unemployed
#
#   What matters most to you in choosing a course Search Magazine  \
# 0                       Better Career Prospects     No       No
# 1                       Better Career Prospects     No       No
# 2                       Better Career Prospects     No       No
# 3                       Better Career Prospects     No       No
# 4                       Better Career Prospects     No       No
#
#   Newspaper Article X Education Forums Newspaper Digital Advertisement  \
# 0                No                 No        No                    No
# 1                No                 No        No                    No
# 2                No                 No        No                    No
# 3                No                 No        No                    No
# 4                No                 No        No                    No
#
#   Through Recommendations Receive More Updates About Our Courses  \
# 0                      No                                     No
# 1                      No                                     No
# 2                      No                                     No
# 3                      No                                     No
# 4                      No                                     No
#
#                                   Tags      Lead Quality  \
# 0          Interested in other courses  Low in Relevance
# 1                              Ringing               NaN
# 2  Will revert after reading the email          Might be
# 3                              Ringing          Not Sure
# 4  Will revert after reading the email          Might be
#
#   Update me on Supply Chain Content Get updates on DM Content    Lead Profile  \
# 0                                No                        No          Select
# 1                                No                        No          Select
# 2                                No                        No  Potential Lead
# 3                                No                        No          Select
# 4                                No                        No          Select
#
#      City Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0  Select                   02.Medium                  02.Medium
# 1  Select                   02.Medium                  02.Medium
# 2  Mumbai                   02.Medium                    01.High
# 3  Mumbai                   02.Medium                    01.High
# 4  Mumbai                   02.Medium                    01.High
#
#    Asymmetrique Activity Score  Asymmetrique Profile Score  \
# 0                         15.0                        15.0
# 1                         15.0                        15.0
# 2                         14.0                        20.0
# 3                         13.0                        17.0
# 4                         15.0                        18.0
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified

# %% [markdown]
# - Prospect ID, Lead Number is unique identification number. This will not help in model building.

# %%
lead.shape
# Out:
# (9240, 37)

# %%
# Statistics analysis of data -
lead.describe(percentiles=[0.1,0.2,0.3,0.5,0.75,0.9,0.95,0.99,1])
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 10%    586361.700000     0.000000     0.000000                     0.000000
# 20%    592772.800000     0.000000     0.000000                     0.000000
# 30%    600313.400000     0.000000     2.000000                    57.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# 90%    650506.100000     1.000000     7.000000                  1380.000000
# 95%    655404.050000     1.000000    10.000000                  1562.000000
# 99%    659592.980000     1.000000    17.000000                  1840.610000
# 100%   660737.000000     1.000000   251.000000                  2272.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# min                0.000000                     7.000000
# 10%                0.000000                    13.000000
# 20%                0.000000                    13.000000
# 30%                1.000000                    14.000000
# 50%                2.000000                    14.000000
# 75%                3.000000                    15.000000
# 90%                5.000000                    16.000000
# 95%                6.000000                    17.000000
# 99%                9.000000                    17.000000
# 100%              55.000000                    18.000000
# max               55.000000                    18.000000
#
#        Asymmetrique Profile Score
# count                 5022.000000
# mean                    16.344883
# std                      1.811395
# min                     11.000000
# 10%                     15.000000
# 20%                     15.000000
# 30%                     15.000000
# 50%                     16.000000
# 75%                     18.000000
# 90%                     19.000000
# 95%                     20.000000
# 99%                     20.000000
# 100%                    20.000000
# max                     20.000000

# %% [markdown]
# - There are no outliers in the data.

# %%
lead.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
#  9   Page Views Per Visit                           9103 non-null   float64
#  10  Last Activity                                  9137 non-null   object
#  11  Country                                        6779 non-null   object
#  12  Specialization                                 7802 non-null   object
#  13  How did you hear about X Education             7033 non-null   object
#  14  What is your current occupation                6550 non-null   object
#  15  What matters most to you in choosing a course  6531 non-null   object
#  16  Search                                         9240 non-null   object
#  17  Magazine                                       9240 non-null   object
#  18  Newspaper Article                              9240 non-null   object
#  19  X Education Forums                             9240 non-null   object
#  20  Newspaper                                      9240 non-null   object
#  21  Digital Advertisement                          9240 non-null   object
#  22  Through Recommendations                        9240 non-null   object
#  23  Receive More Updates About Our Courses         9240 non-null   object
#  24  Tags                                           5887 non-null   object
#  25  Lead Quality                                   4473 non-null   object
#  26  Update me on Supply Chain Content              9240 non-null   object
#  27  Get updates on DM Content                      9240 non-null   object
#  28  Lead Profile                                   6531 non-null   object
#  29  City                                           7820 non-null   object
#  30  Asymmetrique Activity Index                    5022 non-null   object
#  31  Asymmetrique Profile Index                     5022 non-null   object
#  32  Asymmetrique Activity Score                    5022 non-null   float64
#  33  Asymmetrique Profile Score                     5022 non-null   float64
#  34  I agree to pay the amount through cheque       9240 non-null   object
#  35  A free copy of Mastering The Interview         9240 non-null   object
#  36  Last Notable Activity                          9240 non-null   object
# dtypes: float64(4), int64(3), object(30)
# memory usage: 2.6+ MB

# %%
# Check for duplicates
lead[lead.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Prospect ID, Lead Number, Lead Origin, Lead Source, Do Not Email, Do Not Call, Converted, TotalVisits, Total Time Spent on Website, Page Views Per Visit, Last Activity, Country, Specialization, How did you hear about X Education, What is your current occupation, What matters most to you in choosing a course, Search, Magazine, Newspaper Article, X Education Forums, Newspaper, Digital Advertisement, Through Recommendations, Receive More Updates About Our Courses, Tags, Lead Quality, Update me on Supply Chain Content, Get updates on DM Content, Lead Profile, City, Asymmetrique Activity Index, Asymmetrique Profile Index, Asymmetrique Activity Score, Asymmetrique Profile Score, I agree to pay the amount through cheque, A free copy of Mastering The Interview, Last Notable Activity]
# Index: []

# %% [markdown]
# - There are no duplicates in the data frame.

# %%
# Check percentage of null values per colunms :
round(lead.isna().mean().sort_values(ascending=False)*100,2)
# Out:
# Lead Quality                                     51.59
# Asymmetrique Activity Index                      45.65
# Asymmetrique Profile Score                       45.65
# Asymmetrique Activity Score                      45.65
# Asymmetrique Profile Index                       45.65
# Tags                                             36.29
# Lead Profile                                     29.32
# What matters most to you in choosing a course    29.32
# What is your current occupation                  29.11
# Country                                          26.63
# How did you hear about X Education               23.89
# Specialization                                   15.56
# City                                             15.37
# Page Views Per Visit                              1.48
# TotalVisits                                       1.48
# Last Activity                                     1.11
# Lead Source                                       0.39
# Receive More Updates About Our Courses            0.00
# I agree to pay the amount through cheque          0.00
# Get updates on DM Content                         0.00
# Update me on Supply Chain Content                 0.00
# A free copy of Mastering The Interview            0.00
# Prospect ID                                       0.00
# Newspaper Article                                 0.00
# Through Recommendations                           0.00
# Digital Advertisement                             0.00
# Newspaper                                         0.00
# X Education Forums                                0.00
# Lead Number                                       0.00
# Magazine                                          0.00
# Search                                            0.00
# Total Time Spent on Website                       0.00
# Converted                                         0.00
# Do Not Call                                       0.00
# Do Not Email                                      0.00
# Lead Origin                                       0.00
# Last Notable Activity                             0.00
# dtype: float64

# %%
# Checking pearson correlation of categorical variable with the columns containing more than 30 % missing values -
lead [["Asymmetrique Profile Score", "Asymmetrique Activity Score", "Converted"]].corr()
# Out:
#                              Asymmetrique Profile Score  \
# Asymmetrique Profile Score                     1.000000
# Asymmetrique Activity Score                   -0.123250
# Converted                                      0.218571
#
#                              Asymmetrique Activity Score  Converted
# Asymmetrique Profile Score                     -0.123250   0.218571
# Asymmetrique Activity Score                     1.000000   0.167962
# Converted                                       0.167962   1.000000

# %% [markdown]
# - Low correlation of both the variable with target variable, hence discard the values.

# %%
# Plot graph to check relation between categorical variables, with high percent of missing values, and target variable
for i in lead [["Lead Quality", "Asymmetrique Activity Index",
       "Asymmetrique Profile Index" ,"Tags"]] :
       plt.figure(figsize=[18,5])
       sns.countplot(x=lead[i], data=lead, hue="Converted",palette=['b','y'])
       plt.xticks(rotation=90)
       plt.show()

# %% [markdown]
# - Tags and read quality seem to have relevance with target variable.
# - So better to impute values rather than discarding the variables

# %%
# Discarding following variable -
lead = lead.drop(["Asymmetrique Activity Index","Asymmetrique Profile Index","Asymmetrique Profile Score", 
                  "Asymmetrique Activity Score","Prospect ID","Lead Number"], axis=1)

# %%
# Checking value count for each variable -
for i in lead.columns:
  print(f"""-------------{i}------------
{lead[i].astype("category").value_counts()}
""")
# Out:
# -------------Lead Origin------------
# Landing Page Submission    4886
# API                        3580
# Lead Add Form               718
# Lead Import                  55
# Quick Add Form                1
# Name: Lead Origin, dtype: int64
#
# -------------Lead Source------------
# Google               2868
# Direct Traffic       2543
# Olark Chat           1755
# Organic Search       1154
# Reference             534
# Welingak Website      142
# Referral Sites        125
# Facebook               55
# bing                    6
# google                  5
# Click2call              4
# Press_Release           2
# Social Media            2
# Live Chat               2
# WeLearn                 1
# Pay per Click Ads       1
# NC_EDM                  1
# blog                    1
# testone                 1
# welearnblog_Home        1
# youtubechannel          1
# Name: Lead Source, dtype: int64
#
# -------------Do Not Email------------
# No     8506
# Yes     734
# Name: Do Not Email, dtype: int64
#
# -------------Do Not Call------------
# No     9238
# Yes       2
# Name: Do Not Call, dtype: int64
#
# -------------Converted------------
# 0    5679
# 1    3561
# Name: Converted, dtype: int64
#
# -------------TotalVisits------------
# 0.0      2189
# 2.0      1680
# 3.0      1306
# 4.0      1120
# 5.0       783
# 6.0       466
# 1.0       395
# 7.0       309
# 8.0       224
# 9.0       164
# 10.0      114
# 11.0       86
# 13.0       48
# 12.0       45
# 14.0       36
# 16.0       21
# 15.0       18
# 17.0       16
# 18.0       15
# 20.0       12
# 19.0        9
# 23.0        6
# 21.0        6
# 24.0        5
# 25.0        5
# 27.0        5
# 22.0        3
# 26.0        2
# 28.0        2
# 29.0        2
# 54.0        1
# 141.0       1
# 115.0       1
# 74.0        1
# 55.0        1
# 30.0        1
# 43.0        1
# 42.0        1
# 41.0        1
# 32.0        1
# 251.0       1
# Name: TotalVisits, dtype: int64
#
# -------------Total Time Spent on Website------------
# 0       2193
# 60        19
# 75        18
# 74        18
# 127       18
#         ...
# 1091       1
# 1088       1
# 1085       1
# 1084       1
# 2272       1
# Name: Total Time Spent on Website, Length: 1731, dtype: int64
#
# -------------Page Views Per Visit------------
# 0.0     2189
# 2.0     1795
# 3.0     1196
# 4.0      896
# 1.0      651
#         ...
# 3.57       1
# 3.8        1
# 3.82       1
# 3.83       1
# 55.0       1
# Name: Page Views Per Visit, Length: 114, dtype: int64
#
# -------------Last Activity------------
# Email Opened                    3437
# SMS Sent                        2745
# Olark Chat Conversation          973
# Page Visited on Website          640
# Converted to Lead                428
# Email Bounced                    326
# Email Link Clicked               267
# Form Submitted on Website        116
# Unreachable                       93
# Unsubscribed                      61
# Had a Phone Conversation          30
# Approached upfront                 9
# View in browser link Clicked       6
# Email Received                     2
# Email Marked Spam                  2
# Resubscribed to emails             1
# Visited Booth in Tradeshow         1
# Name: Last Activity, dtype: int64
#
# -------------Country------------
# India                   6492
# United States             69
# United Arab Emirates      53
# Singapore                 24
# Saudi Arabia              21
# United Kingdom            15
# Australia                 13
# Qatar                     10
# Bahrain                    7
# Hong Kong                  7
# France                     6
# Oman                       6
# unknown                    5
# Kuwait                     4
# Nigeria                    4
# South Africa               4
# Germany                    4
# Canada                     4
# Sweden                     3
# Uganda                     2
# Philippines                2
# Asia/Pacific Region        2
# Italy                      2
# Ghana                      2
# China                      2
# Belgium                    2
# Bangladesh                 2
# Netherlands                2
# Malaysia                   1
# Liberia                    1
# Russia                     1
# Kenya                      1
# Indonesia                  1
# Sri Lanka                  1
# Switzerland                1
# Tanzania                   1
# Denmark                    1
# Vietnam                    1
# Name: Country, dtype: int64
#
# -------------Specialization------------
# Select                               1942
# Finance Management                    976
# Human Resource Management             848
# Marketing Management                  838
# Operations Management                 503
# Business Administration               403
# IT Projects Management                366
# Supply Chain Management               349
# Banking, Investment And Insurance     338
# Media and Advertising                 203
# Travel and Tourism                    203
# International Business                178
# Healthcare Management                 159
# Hospitality Management                114
# E-COMMERCE                            112
# Retail Management                     100
# Rural and Agribusiness                 73
# E-Business                             57
# Services Excellence                    40
# Name: Specialization, dtype: int64
#
# -------------How did you hear about X Education------------
# Select                   5043
# Online Search             808
# Word Of Mouth             348
# Student of SomeSchool     310
# Other                     186
# Multiple Sources          152
# Advertisements             70
# Social Media               67
# Email                      26
# SMS                        23
# Name: How did you hear about X Education, dtype: int64
#
# -------------What is your current occupation------------
# Unemployed              5600
# Working Professional     706
# Student                  210
# Other                     16
# Housewife                 10
# Businessman                8
# Name: What is your current occupation, dtype: int64
#
# -------------What matters most to you in choosing a course------------
# Better Career Prospects      6528
# Flexibility & Convenience       2
# Other                           1
# Name: What matters most to you in choosing a course, dtype: int64
#
# -------------Search------------
# No     9226
# Yes      14
# Name: Search, dtype: int64
#
# -------------Magazine------------
# No    9240
# Name: Magazine, dtype: int64
#
# -------------Newspaper Article------------
# No     9238
# Yes       2
# Name: Newspaper Article, dtype: int64
#
# -------------X Education Forums------------
# No     9239
# Yes       1
# Name: X Education Forums, dtype: int64
#
# -------------Newspaper------------
# No     9239
# Yes       1
# Name: Newspaper, dtype: int64
#
# -------------Digital Advertisement------------
# No     9236
# Yes       4
# Name: Digital Advertisement, dtype: int64
#
# -------------Through Recommendations------------
# No     9233
# Yes       7
# Name: Through Recommendations, dtype: int64
#
# -------------Receive More Updates About Our Courses------------
# No    9240
# Name: Receive More Updates About Our Courses, dtype: int64
#
# -------------Tags------------
# Will revert after reading the email                  2072
# Ringing                                              1203
# Interested in other courses                           513
# Already a student                                     465
# Closed by Horizzon                                    358
# switched off                                          240
# Busy                                                  186
# Lost to EINS                                          175
# Not doing further education                           145
# Interested  in full time MBA                          117
# Graduation in progress                                111
# invalid number                                         83
# Diploma holder (Not Eligible)                          63
# wrong number given                                     47
# opp hangup                                             33
# number not provided                                    27
# in touch with EINS                                     12
# Lost to Others                                          7
# Still Thinking                                          6
# Want to take admission but has financial problems       6
# Interested in Next batch                                5
# In confusion whether part time or DLP                   5
# Lateral student                                         3
# Shall take in the next coming month                     2
# University not recognized                               2
# Recognition issue (DEC approval)                        1
# Name: Tags, dtype: int64
#
# -------------Lead Quality------------
# Might be             1560
# Not Sure             1092
# High in Relevance     637
# Worst                 601
# Low in Relevance      583
# Name: Lead Quality, dtype: int64
#
# -------------Update me on Supply Chain Content------------
# No    9240
# Name: Update me on Supply Chain Content, dtype: int64
#
# -------------Get updates on DM Content------------
# No    9240
# Name: Get updates on DM Content, dtype: int64
#
# -------------Lead Profile------------
# Select                         4146
# Potential Lead                 1613
# Other Leads                     487
# Student of SomeSchool           241
# Lateral Student                  24
# Dual Specialization Student      20
# Name: Lead Profile, dtype: int64
#
# -------------City------------
# Mumbai                         3222
# Select                         2249
# Thane & Outskirts               752
# Other Cities                    686
# Other Cities of Maharashtra     457
# Other Metro Cities              380
# Tier II Cities                   74
# Name: City, dtype: int64
#
# -------------I agree to pay the amount through cheque------------
# No    9240
# Name: I agree to pay the amount through cheque, dtype: int64
#
# -------------A free copy of Mastering The Interview------------
# No     6352
# Yes    2888
# Name: A free copy of Mastering The Interview, dtype: int64
#
# -------------Last Notable Activity------------
# Modified                        3407
# Email Opened                    2827
# SMS Sent                        2172
# Page Visited on Website          318
# Olark Chat Conversation          183
# Email Link Clicked               173
# Email Bounced                     60
# Unsubscribed                      47
# Unreachable                       32
# Had a Phone Conversation          14
# Email Marked Spam                  2
# Approached upfront                 1
# Email Received                     1
# Form Submitted on Website          1
# Resubscribed to emails             1
# View in browser link Clicked       1
# Name: Last Notable Activity, dtype: int64

# %% [markdown]
# - There are columns which have very less variation in the classes. Hence it will not provide help in identifying the patterns in the data. Therefore we discard the values -

# %%
# Drop variable with heavy imbalance in the class -
lead = lead.drop(["Country","What matters most to you in choosing a course","Search",
       "Magazine","Newspaper Article","X Education Forums","Newspaper",
       "Digital Advertisement","Through Recommendations","Receive More Updates About Our Courses",
       "Update me on Supply Chain Content","Get updates on DM Content",
       "I agree to pay the amount through cheque","Do Not Call"],axis=1)

# %% [markdown]
# - We observed Select class in many variables. This is as good as null values.
# - First we will replace with null values and then impute the values.

# %%
# Replace select-
select = ["How did you hear about X Education","Specialization","Lead Profile","City"]
for i in select:
  lead[i].replace("Select",np.nan,inplace=True)

# %%
# Checking the null values again in the dataframe.
lead.isna().mean()
# Out:
# Lead Origin                               0.000000
# Lead Source                               0.003896
# Do Not Email                              0.000000
# Converted                                 0.000000
# TotalVisits                               0.014827
# Total Time Spent on Website               0.000000
# Page Views Per Visit                      0.014827
# Last Activity                             0.011147
# Specialization                            0.365801
# How did you hear about X Education        0.784632
# What is your current occupation           0.291126
# Tags                                      0.362879
# Lead Quality                              0.515909
# Lead Profile                              0.741883
# City                                      0.397078
# A free copy of Mastering The Interview    0.000000
# Last Notable Activity                     0.000000
# dtype: float64

# %% [markdown]
# - The percentage of missing values for "How did you hear about X Education" and "Lead Profile" is above 60 % after replacing the "select" class with NaN values.
# - Hence we will dicard both the values

# %%
# Dropping two more variables
lead.drop(["How did you hear about X Education","Lead Profile"], axis=1,inplace=True)

# %%
# Impute the missing values in same proportion as present values for categorical variable -
cat_impute = ["Lead Source","Specialization","What is your current occupation","Tags","Lead Quality","City"]

# %%
# Create a function to replace in proportion
def replace_with_proportion(frame, column):
    isnull = frame[column].isna()
    countframe = pd.DataFrame(data=frame[column].value_counts()).reset_index()
    countframe.columns = ["name","count"]
    countframe["proportion"] = countframe["count"]/countframe["count"].sum()
    fill_array = np.random.choice(a=countframe["name"],size=frame[column].isna().sum(),p=countframe["proportion"])
    frame.loc[isnull,column] = fill_array
    return frame

# %%
# Impute the values
for variable in cat_impute:
  replace_with_proportion(lead, variable)

# %%
# Check the percentage missing values -
lead.isna().mean() *100
# Out:
# Lead Origin                               0.000000
# Lead Source                               0.000000
# Do Not Email                              0.000000
# Converted                                 0.000000
# TotalVisits                               1.482684
# Total Time Spent on Website               0.000000
# Page Views Per Visit                      1.482684
# Last Activity                             1.114719
# Specialization                            0.000000
# What is your current occupation           0.000000
# Tags                                      0.000000
# Lead Quality                              0.000000
# City                                      0.000000
# A free copy of Mastering The Interview    0.000000
# Last Notable Activity                     0.000000
# dtype: float64

# %%
# The pending missing values are less than 2 %, we can drop the rows -
lead.dropna(inplace=True)

# %%
# Check the missing values -
lead.isna().mean()
# Out:
# Lead Origin                               0.0
# Lead Source                               0.0
# Do Not Email                              0.0
# Converted                                 0.0
# TotalVisits                               0.0
# Total Time Spent on Website               0.0
# Page Views Per Visit                      0.0
# Last Activity                             0.0
# Specialization                            0.0
# What is your current occupation           0.0
# Tags                                      0.0
# Lead Quality                              0.0
# City                                      0.0
# A free copy of Mastering The Interview    0.0
# Last Notable Activity                     0.0
# dtype: float64

# %%
#Checking the dimension of final dataframe.
lead.shape
# Out:
# (9103, 15)

# %% [markdown]
# # EDA

# %% [markdown]
# - Univariate Analysis -

# %%
# Check the proportion of the target variable "Converted" -
plt.pie(lead["Converted"].value_counts(),labels = lead["Converted"].value_counts().index, 
        autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# - Data is balanced.

# %%
# Check the dataframe -
lead.head()
# Out:
#                Lead Origin     Lead Source Do Not Email  Converted  \
# 0                      API      Olark Chat           No          0
# 1                      API  Organic Search           No          0
# 2  Landing Page Submission  Direct Traffic           No          1
# 3  Landing Page Submission  Direct Traffic           No          0
# 4  Landing Page Submission          Google           No          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity             Specialization  \
# 0  Page Visited on Website  Human Resource Management
# 1             Email Opened      Operations Management
# 2             Email Opened    Business Administration
# 3              Unreachable      Media and Advertising
# 4        Converted to Lead       Marketing Management
#
#   What is your current occupation                                 Tags  \
# 0                      Unemployed          Interested in other courses
# 1                      Unemployed                              Ringing
# 2                         Student  Will revert after reading the email
# 3                      Unemployed                              Ringing
# 4                      Unemployed  Will revert after reading the email
#
#        Lead Quality               City A free copy of Mastering The Interview  \
# 0  Low in Relevance  Thane & Outskirts                                     No
# 1          Might be  Thane & Outskirts                                     No
# 2          Might be             Mumbai                                    Yes
# 3          Not Sure             Mumbai                                     No
# 4          Might be             Mumbai                                     No
#
#   Last Notable Activity
# 0              Modified
# 1          Email Opened
# 2          Email Opened
# 3              Modified
# 4              Modified

# %%
# Separate the categorical and continuous variable.
categorical = [i for i in lead.columns if lead[i].nunique() < 30]
categorical.remove("Converted")
continuous = [i for i in lead.columns if lead[i].nunique() >= 30]

# %%
# Create a function to plot the graph
def univariate_plot(data,predictor,target):
  plt.figure(figsize=[18,5])
  plt.subplot(1,2,1)
  sns.histplot(x=predictor, data=lead, hue=target, 
               shrink=0.8, multiple="dodge",log_scale=(False,True))
  plt.xticks(rotation=90)
  plt.subplot(1,2,2)
  data = lead[[predictor,target]].groupby(predictor).mean()
  sns.barplot(x=data.index,y=data[target])
  plt.xticks(rotation=90)
  return plt.show()

# %%
# Segmented Analysis with 
for i in categorical:
  univariate_plot(lead,i,"Converted")

# %%
# Box plots for continuous varible
plt.figure(figsize=[18,5])
for i,j in enumerate(continuous):
  plt.subplot(1,3,i+1)
  sns.boxplot(data=lead,y= j, x="Converted")
plt.show()

# %% [markdown]
# - Bivariate Analysis

# %%
# Plot the pairplot for all the continuous variables -
sns.pairplot(lead,height=3,aspect=1.5 ,hue="Converted")
plt.show()

# %%
# Categorical VS Continuous -
sns.catplot(data=lead, x="Specialization", y="Total Time Spent on Website", 
            kind="box",hue="Converted",height=5,aspect=4)
plt.xticks(rotation=90)
plt.show()

# %%
# Multivariate Analysis -
sns.heatmap(lead.corr(),annot=True)
plt.show()

# %% [markdown]
# # Modelling

# %%
lead.head()
# Out:
#                Lead Origin     Lead Source  Do Not Email  Converted  \
# 0                      API      Olark Chat             0          0
# 1                      API  Organic Search             0          0
# 2  Landing Page Submission  Direct Traffic             0          1
# 3  Landing Page Submission  Direct Traffic             0          0
# 4  Landing Page Submission          Google             0          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity             Specialization  \
# 0  Page Visited on Website  Human Resource Management
# 1             Email Opened      Operations Management
# 2             Email Opened    Business Administration
# 3              Unreachable      Media and Advertising
# 4        Converted to Lead       Marketing Management
#
#   What is your current occupation                                 Tags  \
# 0                      Unemployed          Interested in other courses
# 1                      Unemployed                              Ringing
# 2                         Student  Will revert after reading the email
# 3                      Unemployed                              Ringing
# 4                      Unemployed  Will revert after reading the email
#
#        Lead Quality               City  \
# 0  Low in Relevance  Thane & Outskirts
# 1          Might be  Thane & Outskirts
# 2          Might be             Mumbai
# 3          Not Sure             Mumbai
# 4          Might be             Mumbai
#
#    A free copy of Mastering The Interview Last Notable Activity
# 0                                       0              Modified
# 1                                       0          Email Opened
# 2                                       1          Email Opened
# 3                                       0              Modified
# 4                                       0              Modified

# %% [markdown]
# ## Data Preparation for Modelling

# %%
# Convert two class variable to binary feature -
list_01 = ["Do Not Email","A free copy of Mastering The Interview"]
for feature in list_01:
  lead[feature]=lead[feature].map({"Yes":1,"No":0})

# %%
# Get the dummies values for higher number of classes -
list_02 = [feature for feature in lead.columns if lead[feature].nunique() >2 and lead[feature].nunique() <30]
dummy = pd.get_dummies(lead[list_02],drop_first=True)

# %%
# Drop the columns for which dummies are created -
lead.drop(list_02,axis =1,inplace=True)

# %%
# Concat the two dataframe -
lead_df = pd.concat([lead,dummy],axis=1)

# %%
# See the correlations of the variable -
corr_df = lead_df.drop("Converted",axis=1)
corr_matrix = corr_df.corr().where(np.triu(np.ones(corr_df.corr().shape),k=1).astype(np.bool))
corr_df = corr_matrix.unstack().reset_index().dropna(subset=[0])
corr_df.columns = ["Var1","Var2", "Correlation"]
corr_df["Correlation"] = corr_df["Correlation"].abs()
corr_df.sort_values(by="Correlation",ascending=False,inplace=True)

# %%
# Creating list for highly correlated variables - Greater than 0.5 -
list_corr = corr_df[corr_df["Correlation"]>0.5]["Var2"].to_list()

# %%
# Drop the same from the dataframe -
lead_df.drop(list_corr,axis=1,inplace=True)

# %%
# Perform Train-Test split
train, test = train_test_split(lead_df,train_size=0.7,random_state=100)
train.shape
# Out:
# (6372, 97)

# %%
# X and y split for training data set -
y_train = train.pop("Converted")
X_train = train
X_train.head()
# Out:
#       Total Time Spent on Website  Lead Source_Direct Traffic  \
# 7962                         1286                           0
# 5520                           60                           1
# 1962                          169                           0
# 1566                         1241                           0
# 9170                            0                           0
#
#       Lead Source_Facebook  Lead Source_Google  Lead Source_Live Chat  \
# 7962                     0                   1                      0
# 5520                     0                   0                      0
# 1962                     0                   1                      0
# 1566                     0                   1                      0
# 9170                     0                   0                      0
#
#       Lead Source_NC_EDM  Lead Source_Olark Chat  Lead Source_Organic Search  \
# 7962                   0                       0                           0
# 5520                   0                       0                           0
# 1962                   0                       0                           0
# 1566                   0                       0                           0
# 9170                   0                       1                           0
#
#       Lead Source_Pay per Click Ads  Lead Source_Press_Release  \
# 7962                              0                          0
# 5520                              0                          0
# 1962                              0                          0
# 1566                              0                          0
# 9170                              0                          0
#
#       Lead Source_Reference  Lead Source_Referral Sites  \
# 7962                      0                           0
# 5520                      0                           0
# 1962                      0                           0
# 1566                      0                           0
# 9170                      0                           0
#
#       Lead Source_Social Media  Lead Source_WeLearn  \
# 7962                         0                    0
# 5520                         0                    0
# 1962                         0                    0
# 1566                         0                    0
# 9170                         0                    0
#
#       Lead Source_Welingak Website  Lead Source_bing  Lead Source_blog  \
# 7962                             0                 0                 0
# 5520                             0                 0                 0
# 1962                             0                 0                 0
# 1566                             0                 0                 0
# 9170                             0                 0                 0
#
#       Lead Source_google  Lead Source_testone  Lead Source_welearnblog_Home  \
# 7962                   0                    0                             0
# 5520                   0                    0                             0
# 1962                   0                    0                             0
# 1566                   0                    0                             0
# 9170                   0                    0                             0
#
#       Lead Source_youtubechannel  Last Activity_Converted to Lead  \
# 7962                           0                                0
# 5520                           0                                0
# 1962                           0                                0
# 1566                           0                                0
# 9170                           0                                0
#
#       Last Activity_Email Bounced  Last Activity_Form Submitted on Website  \
# 7962                            0                                        0
# 5520                            0                                        0
# 1962                            0                                        0
# 1566                            0                                        0
# 9170                            0                                        0
#
#       Last Activity_Olark Chat Conversation  \
# 7962                                      0
# 5520                                      0
# 1962                                      0
# 1566                                      0
# 9170                                      0
#
#       Last Activity_View in browser link Clicked  \
# 7962                                           0
# 5520                                           0
# 1962                                           0
# 1566                                           0
# 9170                                           0
#
#       Last Activity_Visited Booth in Tradeshow  \
# 7962                                         0
# 5520                                         0
# 1962                                         0
# 1566                                         0
# 9170                                         0
#
#       Specialization_Business Administration  Specialization_E-Business  \
# 7962                                       0                          0
# 5520                                       0                          0
# 1962                                       0                          0
# 1566                                       0                          0
# 9170                                       0                          0
#
#       Specialization_E-COMMERCE  Specialization_Finance Management  \
# 7962                          0                                  0
# 5520                          0                                  0
# 1962                          0                                  0
# 1566                          0                                  0
# 9170                          0                                  0
#
#       Specialization_Healthcare Management  \
# 7962                                     0
# 5520                                     0
# 1962                                     0
# 1566                                     0
# 9170                                     0
#
#       Specialization_Hospitality Management  \
# 7962                                      0
# 5520                                      0
# 1962                                      0
# 1566                                      0
# 9170                                      0
#
#       Specialization_Human Resource Management  \
# 7962                                         0
# 5520                                         0
# 1962                                         0
# 1566                                         0
# 9170                                         0
#
#       Specialization_IT Projects Management  \
# 7962                                      1
# 5520                                      0
# 1962                                      1
# 1566                                      0
# 9170                                      0
#
#       Specialization_International Business  \
# 7962                                      0
# 5520                                      1
# 1962                                      0
# 1566                                      0
# 9170                                      0
#
#       Specialization_Marketing Management  \
# 7962                                    0
# 5520                                    0
# 1962                                    0
# 1566                                    0
# 9170                                    0
#
#       Specialization_Media and Advertising  \
# 7962                                     0
# 5520                                     0
# 1962                                     0
# 1566                                     0
# 9170                                     0
#
#       Specialization_Operations Management  Specialization_Retail Management  \
# 7962                                     0                                 0
# 5520                                     0                                 0
# 1962                                     0                                 0
# 1566                                     1                                 0
# 9170                                     0                                 1
#
#       Specialization_Rural and Agribusiness  \
# 7962                                      0
# 5520                                      0
# 1962                                      0
# 1566                                      0
# 9170                                      0
#
#       Specialization_Services Excellence  \
# 7962                                   0
# 5520                                   0
# 1962                                   0
# 1566                                   0
# 9170                                   0
#
#       Specialization_Supply Chain Management  \
# 7962                                       0
# 5520                                       0
# 1962                                       0
# 1566                                       0
# 9170                                       0
#
#       Specialization_Travel and Tourism  \
# 7962                                  0
# 5520                                  0
# 1962                                  0
# 1566                                  0
# 9170                                  0
#
#       What is your current occupation_Housewife  \
# 7962                                          0
# 5520                                          0
# 1962                                          0
# 1566                                          0
# 9170                                          0
#
#       What is your current occupation_Other  \
# 7962                                      0
# 5520                                      0
# 1962                                      0
# 1566                                      0
# 9170                                      0
#
#       What is your current occupation_Student  \
# 7962                                        0
# 5520                                        0
# 1962                                        0
# 1566                                        0
# 9170                                        0
#
#       What is your current occupation_Working Professional  Tags_Busy  \
# 7962                                                  0             0
# 5520                                                  0             1
# 1962                                                  0             0
# 1566                                                  1             0
# 9170                                                  0             0
#
#       Tags_Closed by Horizzon  Tags_Diploma holder (Not Eligible)  \
# 7962                        0                                   0
# 5520                        0                                   0
# 1962                        0                                   0
# 1566                        0                                   0
# 9170                        0                                   0
#
#       Tags_Graduation in progress  Tags_In confusion whether part time or DLP  \
# 7962                            0                                           0
# 5520                            0                                           0
# 1962                            0                                           0
# 1566                            0                                           0
# 9170                            0                                           0
#
#       Tags_Interested  in full time MBA  Tags_Interested in Next batch  \
# 7962                                  0                              0
# 5520                                  0                              0
# 1962                                  0                              0
# 1566                                  0                              0
# 9170                                  0                              0
#
#       Tags_Interested in other courses  Tags_Lateral student  \
# 7962                                 0                     0
# 5520                                 0                     0
# 1962                                 0                     0
# 1566                                 0                     0
# 9170                                 0                     0
#
#       Tags_Lost to EINS  Tags_Lost to Others  \
# 7962                  0                    0
# 5520                  0                    0
# 1962                  0                    0
# 1566                  0                    0
# 9170                  0                    0
#
#       Tags_Not doing further education  Tags_Recognition issue (DEC approval)  \
# 7962                                 0                                      0
# 5520                                 0                                      0
# 1962                                 0                                      0
# 1566                                 0                                      0
# 9170                                 0                                      0
#
#       Tags_Ringing  Tags_Shall take in the next coming month  \
# 7962             0                                         0
# 5520             0                                         0
# 1962             0                                         0
# 1566             0                                         0
# 9170             0                                         0
#
#       Tags_Still Thinking  Tags_University not recognized  \
# 7962                    0                               0
# 5520                    0                               0
# 1962                    0                               0
# 1566                    0                               0
# 9170                    0                               0
#
#       Tags_Want to take admission but has financial problems  \
# 7962                                                  0
# 5520                                                  0
# 1962                                                  0
# 1566                                                  0
# 9170                                                  0
#
#       Tags_Will revert after reading the email  Tags_in touch with EINS  \
# 7962                                         0                        0
# 5520                                         0                        0
# 1962                                         0                        0
# 1566                                         1                        0
# 9170                                         0                        0
#
#       Tags_invalid number  Tags_number not provided  Tags_opp hangup  \
# 7962                    0                         1                0
# 5520                    0                         0                0
# 1962                    0                         0                0
# 1566                    0                         0                0
# 9170                    0                         0                0
#
#       Tags_switched off  Tags_wrong number given  \
# 7962                  0                        0
# 5520                  0                        0
# 1962                  1                        0
# 1566                  0                        0
# 9170                  0                        0
#
#       Lead Quality_Low in Relevance  Lead Quality_Might be  \
# 7962                              0                      1
# 5520                              0                      1
# 1962                              0                      0
# 1566                              0                      1
# 9170                              0                      1
#
#       Lead Quality_Not Sure  Lead Quality_Worst  City_Other Cities  \
# 7962                      0                   0                  0
# 5520                      0                   0                  0
# 1962                      1                   0                  0
# 1566                      0                   0                  0
# 9170                      0                   0                  0
#
#       City_Other Cities of Maharashtra  City_Other Metro Cities  \
# 7962                                 0                        0
# 5520                                 0                        0
# 1962                                 0                        0
# 1566                                 0                        0
# 9170                                 0                        0
#
#       City_Thane & Outskirts  City_Tier II Cities  \
# 7962                       0                    0
# 5520                       0                    0
# 1962                       0                    0
# 1566                       0                    0
# 9170                       0                    0
#
#       Last Notable Activity_Email Bounced  \
# 7962                                    0
# 5520                                    0
# 1962                                    0
# 1566                                    0
# 9170                                    0
#
#       Last Notable Activity_Email Link Clicked  \
# 7962                                         0
# 5520                                         0
# 1962                                         0
# 1566                                         0
# 9170                                         0
#
#       Last Notable Activity_Email Marked Spam  \
# 7962                                        0
# 5520                                        0
# 1962                                        0
# 1566                                        0
# 9170                                        0
#
#       Last Notable Activity_Email Received  \
# 7962                                     0
# 5520                                     0
# 1962                                     0
# 1566                                     0
# 9170                                     0
#
#       Last Notable Activity_Form Submitted on Website  \
# 7962                                                0
# 5520                                                0
# 1962                                                0
# 1566                                                0
# 9170                                                0
#
#       Last Notable Activity_Had a Phone Conversation  \
# 7962                                               0
# 5520                                               0
# 1962                                               0
# 1566                                               0
# 9170                                               0
#
#       Last Notable Activity_Modified  \
# 7962                               0
# 5520                               0
# 1962                               1
# 1566                               0
# 9170                               0
#
#       Last Notable Activity_Olark Chat Conversation  \
# 7962                                              0
# 5520                                              0
# 1962                                              0
# 1566                                              0
# 9170                                              0
#
#       Last Notable Activity_Page Visited on Website  \
# 7962                                              0
# 5520                                              0
# 1962                                              0
# 1566                                              0
# 9170                                              0
#
#       Last Notable Activity_Resubscribed to emails  \
# 7962                                             0
# 5520                                             0
# 1962                                             0
# 1566                                             0
# 9170                                             0
#
#       Last Notable Activity_SMS Sent  Last Notable Activity_Unreachable  \
# 7962                               1                                  0
# 5520                               0                                  0
# 1962                               0                                  0
# 1566                               0                                  0
# 9170                               0                                  0
#
#       Last Notable Activity_Unsubscribed  \
# 7962                                   0
# 5520                                   0
# 1962                                   0
# 1566                                   0
# 9170                                   0
#
#       Last Notable Activity_View in browser link Clicked
# 7962                                                  0
# 5520                                                  0
# 1962                                                  0
# 1566                                                  0
# 9170                                                  0

# %% [markdown]
# - As we have only one continuous variable, no need of scaling

# %%
# Using RFE get the important features -
linear_class = LogisticRegression(random_state=45)
linear_fit = linear_class.fit(X_train,y_train)

# %%
# Select twenty important feature for training the model
rfe = RFE(estimator=linear_fit,n_features_to_select=20)
rfe = rfe.fit(X_train,y_train)

# %%
# Columns to consider for first model -
cols = X_train.columns[rfe.support_]

# %%
# Listing down the columns
cols = ['Lead Source_Reference',
 'Lead Source_Welingak Website',
 'Last Activity_Email Bounced',
 'Last Activity_Olark Chat Conversation',
 'Tags_Busy',
 'Tags_Closed by Horizzon',
 'Tags_In confusion whether part time or DLP',
 'Tags_Interested in Next batch',
 'Tags_Lateral student',
 'Tags_Lost to EINS',
 'Tags_Ringing',
 'Tags_Will revert after reading the email',
 'Tags_in touch with EINS',
 'Tags_invalid number',
 'Tags_switched off',
 'Tags_wrong number given',
 'Last Notable Activity_Email Bounced',
 'Last Notable Activity_Had a Phone Conversation',
 'Last Notable Activity_SMS Sent',
 'Last Notable Activity_Unreachable']

# %% [markdown]
# ## Model No 1
#
# - Using the 20 Features received through RFE, we will build the first model

# %%
X_train_1 = X_train[cols]
X_train_1_sm = sm.add_constant(X_train_1)
Model_1 = sm.GLM(y_train,X_train_1_sm,family=sm.families.Binomial()).fit()
print(Model_1.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 6372
# Model:                            GLM   Df Residuals:                     6351
# Model Family:                Binomial   Df Model:                           20
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2314.2
# Date:                Tue, 27 Dec 2022   Deviance:                       4628.4
# Time:                        17:24:08   Pearson chi2:                 7.39e+03
# No. Iterations:                    20
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             -2.3528      0.093    -25.255      0.000      -2.535      -2.170
# Lead Source_Reference                              2.0507      0.245      8.387      0.000       1.571       2.530
# Lead Source_Welingak Website                       5.3937      0.745      7.239      0.000       3.933       6.854
# Last Activity_Email Bounced                       -2.4905      0.404     -6.172      0.000      -3.281      -1.700
# Last Activity_Olark Chat Conversation             -1.7997      0.152    -11.817      0.000      -2.098      -1.501
# Tags_Busy                                          1.2848      0.189      6.806      0.000       0.915       1.655
# Tags_Closed by Horizzon                            2.8918      0.160     18.054      0.000       2.578       3.206
# Tags_In confusion whether part time or DLP         1.1877      1.142      1.040      0.298      -1.051       3.426
# Tags_Interested in Next batch                      2.1496      1.092      1.968      0.049       0.009       4.291
# Tags_Lateral student                              22.9822   1.25e+04      0.002      0.999   -2.45e+04    2.45e+04
# Tags_Lost to EINS                                  3.2490      0.185     17.595      0.000       2.887       3.611
# Tags_Ringing                                      -0.9447      0.147     -6.422      0.000      -1.233      -0.656
# Tags_Will revert after reading the email           2.8456      0.106     26.885      0.000       2.638       3.053
# Tags_in touch with EINS                            1.3731      0.677      2.029      0.042       0.047       2.699
# Tags_invalid number                               -0.8859      0.429     -2.063      0.039      -1.728      -0.044
# Tags_switched off                                 -0.6108      0.229     -2.664      0.008      -1.060      -0.161
# Tags_wrong number given                           -0.7467      0.513     -1.454      0.146      -1.753       0.260
# Last Notable Activity_Email Bounced                1.5171      0.642      2.365      0.018       0.260       2.774
# Last Notable Activity_Had a Phone Conversation     1.5867      1.062      1.494      0.135      -0.495       3.669
# Last Notable Activity_SMS Sent                     2.0431      0.101     20.296      0.000       1.846       2.240
# Last Notable Activity_Unreachable                  1.0848      0.544      1.995      0.046       0.019       2.151
# ==================================================================================================================

# %%
# Checking the VIF
X = X_train_1
vif = pd.DataFrame()
vif["features"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["VIF"] = round(vif["VIF"] ,2)
vif.sort_values(by = "VIF", ascending = False,inplace = True)
vif
# Out:
#                                           features   VIF
# 2                      Last Activity_Email Bounced  1.27
# 16             Last Notable Activity_Email Bounced  1.25
# 4                                        Tags_Busy  1.04
# 1                     Lead Source_Welingak Website  1.03
# 19               Last Notable Activity_Unreachable  1.01
# 9                                Tags_Lost to EINS  1.01
# 13                             Tags_invalid number  1.01
# 17  Last Notable Activity_Had a Phone Conversation  1.01
# 15                         Tags_wrong number given  1.01
# 6       Tags_In confusion whether part time or DLP  1.00
# 7                    Tags_Interested in Next batch  1.00
# 8                             Tags_Lateral student  1.00
# 12                         Tags_in touch with EINS  1.00
# 5                          Tags_Closed by Horizzon  0.33
# 3            Last Activity_Olark Chat Conversation  0.28
# 18                  Last Notable Activity_SMS Sent  0.25
# 0                            Lead Source_Reference  0.20
# 11        Tags_Will revert after reading the email  0.11
# 14                               Tags_switched off  0.04
# 10                                    Tags_Ringing  0.00

# %% [markdown]
# ## Model No 2
#
# Drop variable - Tags_Lateral student - based on significance

# %%
# Build the Model -
cols.remove("Tags_Lateral student")
X_train_1 = X_train[cols]
X_train_1_sm = sm.add_constant(X_train_1)
Model_2 = sm.GLM(y_train,X_train_1_sm,family=sm.families.Binomial()).fit()
print(Model_2.summary())

# Check the VIF -
X = X_train_1
vif = pd.DataFrame()
vif["features"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["VIF"] = round(vif["VIF"] ,2)
vif.sort_values(by = "VIF", ascending = False,inplace = True)
print("\n",vif)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 6372
# Model:                            GLM   Df Residuals:                     6352
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2320.1
# Date:                Tue, 27 Dec 2022   Deviance:                       4640.2
# Time:                        17:24:36   Pearson chi2:                 7.41e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             -2.3326      0.092    -25.252      0.000      -2.514      -2.152
# Lead Source_Reference                              2.0576      0.244      8.428      0.000       1.579       2.536
# Lead Source_Welingak Website                       5.3920      0.745      7.236      0.000       3.932       6.853
# Last Activity_Email Bounced                       -2.4927      0.403     -6.179      0.000      -3.283      -1.702
# Last Activity_Olark Chat Conversation             -1.8015      0.152    -11.833      0.000      -2.100      -1.503
# Tags_Busy                                          1.2640      0.188      6.708      0.000       0.895       1.633
# Tags_Closed by Horizzon                            2.8711      0.160     17.978      0.000       2.558       3.184
# Tags_In confusion whether part time or DLP         1.1676      1.142      1.022      0.307      -1.071       3.406
# Tags_Interested in Next batch                      2.1286      1.093      1.948      0.051      -0.013       4.270
# Tags_Lost to EINS                                  3.2290      0.184     17.523      0.000       2.868       3.590
# Tags_Ringing                                      -0.9662      0.147     -6.590      0.000      -1.254      -0.679
# Tags_Will revert after reading the email           2.8253      0.105     26.866      0.000       2.619       3.031
# Tags_in touch with EINS                            1.3526      0.677      1.999      0.046       0.027       2.679
# Tags_invalid number                               -0.9072      0.429     -2.113      0.035      -1.749      -0.066
# Tags_switched off                                 -0.6321      0.229     -2.761      0.006      -1.081      -0.183
# Tags_wrong number given                           -0.7680      0.513     -1.496      0.135      -1.774       0.238
# Last Notable Activity_Email Bounced                1.5155      0.641      2.364      0.018       0.259       2.772
# Last Notable Activity_Had a Phone Conversation     1.5868      1.062      1.494      0.135      -0.495       3.669
# Last Notable Activity_SMS Sent                     2.0447      0.101     20.341      0.000       1.848       2.242
# Last Notable Activity_Unreachable                  1.0818      0.543      1.992      0.046       0.017       2.146
# ==================================================================================================================
#
#                                            features   VIF
# 2                      Last Activity_Email Bounced  1.27
# 15             Last Notable Activity_Email Bounced  1.25
# 4                                        Tags_Busy  1.03
# 1                     Lead Source_Welingak Website  1.03
# 18               Last Notable Activity_Unreachable  1.01
# 8                                Tags_Lost to EINS  1.01
# 12                             Tags_invalid number  1.01
# 16  Last Notable Activity_Had a Phone Conversation  1.01
# 14                         Tags_wrong number given  1.01
# 6       Tags_In confusion whether part time or DLP  1.00
# 7                    Tags_Interested in Next batch  1.00
# 11                         Tags_in touch with EINS  1.00
# 5                          Tags_Closed by Horizzon  0.33
# 3            Last Activity_Olark Chat Conversation  0.28
# 17                  Last Notable Activity_SMS Sent  0.25
# 0                            Lead Source_Reference  0.20
# 10        Tags_Will revert after reading the email  0.11
# 13                               Tags_switched off  0.04
# 9                                     Tags_Ringing  0.00

# %% [markdown]
# ## Model No 3
#
# - Drop "Tags_In confusion whether part time or DLP"

# %%
# Build the model
cols.remove("Tags_In confusion whether part time or DLP")
X_train_1 = X_train[cols]
X_train_1_sm = sm.add_constant(X_train_1)
Model_3 = sm.GLM(y_train,X_train_1_sm,family=sm.families.Binomial()).fit()
print(Model_3.summary())

# Check VIF -
X = X_train_1
vif = pd.DataFrame()
vif["features"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["VIF"] = round(vif["VIF"] ,2)
vif.sort_values(by = "VIF", ascending = False,inplace = True)
print("\n",vif)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 6372
# Model:                            GLM   Df Residuals:                     6353
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2320.5
# Date:                Tue, 27 Dec 2022   Deviance:                       4641.0
# Time:                        17:25:46   Pearson chi2:                 7.40e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             -2.3273      0.092    -25.276      0.000      -2.508      -2.147
# Lead Source_Reference                              2.0572      0.244      8.428      0.000       1.579       2.536
# Lead Source_Welingak Website                       5.3908      0.745      7.234      0.000       3.930       6.851
# Last Activity_Email Bounced                       -2.4935      0.403     -6.181      0.000      -3.284      -1.703
# Last Activity_Olark Chat Conversation             -1.8014      0.152    -11.833      0.000      -2.100      -1.503
# Tags_Busy                                          1.2593      0.188      6.688      0.000       0.890       1.628
# Tags_Closed by Horizzon                            2.8659      0.160     17.964      0.000       2.553       3.179
# Tags_Interested in Next batch                      2.1240      1.093      1.944      0.052      -0.017       4.265
# Tags_Lost to EINS                                  3.2237      0.184     17.508      0.000       2.863       3.585
# Tags_Ringing                                      -0.9705      0.146     -6.626      0.000      -1.258      -0.683
# Tags_Will revert after reading the email           2.8202      0.105     26.881      0.000       2.615       3.026
# Tags_in touch with EINS                            1.3475      0.676      1.992      0.046       0.022       2.673
# Tags_invalid number                               -0.9115      0.429     -2.124      0.034      -1.753      -0.070
# Tags_switched off                                 -0.6365      0.229     -2.781      0.005      -1.085      -0.188
# Tags_wrong number given                           -0.7724      0.513     -1.505      0.132      -1.778       0.234
# Last Notable Activity_Email Bounced                1.5151      0.641      2.364      0.018       0.259       2.771
# Last Notable Activity_Had a Phone Conversation     1.5866      1.062      1.494      0.135      -0.496       3.669
# Last Notable Activity_SMS Sent                     2.0433      0.100     20.337      0.000       1.846       2.240
# Last Notable Activity_Unreachable                  1.0808      0.543      1.991      0.046       0.017       2.145
# ==================================================================================================================
#
#                                            features   VIF
# 2                      Last Activity_Email Bounced  1.27
# 14             Last Notable Activity_Email Bounced  1.25
# 4                                        Tags_Busy  1.03
# 1                     Lead Source_Welingak Website  1.03
# 17               Last Notable Activity_Unreachable  1.01
# 7                                Tags_Lost to EINS  1.01
# 11                             Tags_invalid number  1.01
# 15  Last Notable Activity_Had a Phone Conversation  1.01
# 13                         Tags_wrong number given  1.01
# 6                    Tags_Interested in Next batch  1.00
# 10                         Tags_in touch with EINS  1.00
# 5                          Tags_Closed by Horizzon  0.33
# 3            Last Activity_Olark Chat Conversation  0.28
# 16                  Last Notable Activity_SMS Sent  0.25
# 0                            Lead Source_Reference  0.20
# 9         Tags_Will revert after reading the email  0.11
# 12                               Tags_switched off  0.04
# 8                                     Tags_Ringing  0.00

# %% [markdown]
# ## Model No 4
#
# Drop "Tags_wrong number given" based on significance -

# %%
# Build the model
cols.remove("Tags_wrong number given")
X_train_1 = X_train[cols]
X_train_1_sm = sm.add_constant(X_train_1)
Model_4 = sm.GLM(y_train,X_train_1_sm,family=sm.families.Binomial()).fit()
print(Model_4.summary())

# Check VIF -
X = X_train_1
vif = pd.DataFrame()
vif["features"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["VIF"] = round(vif["VIF"] ,2)
vif.sort_values(by = "VIF", ascending = False,inplace = True)
print("\n",vif)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 6372
# Model:                            GLM   Df Residuals:                     6354
# Model Family:                Binomial   Df Model:                           17
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2321.8
# Date:                Tue, 27 Dec 2022   Deviance:                       4643.6
# Time:                        17:27:18   Pearson chi2:                 7.36e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             -2.3523      0.091    -25.754      0.000      -2.531      -2.173
# Lead Source_Reference                              2.0599      0.244      8.436      0.000       1.581       2.539
# Lead Source_Welingak Website                       5.3874      0.745      7.234      0.000       3.928       6.847
# Last Activity_Email Bounced                       -2.4953      0.403     -6.186      0.000      -3.286      -1.705
# Last Activity_Olark Chat Conversation             -1.8019      0.152    -11.832      0.000      -2.100      -1.503
# Tags_Busy                                          1.2912      0.187      6.898      0.000       0.924       1.658
# Tags_Closed by Horizzon                            2.8912      0.159     18.176      0.000       2.579       3.203
# Tags_Interested in Next batch                      2.1588      1.090      1.980      0.048       0.022       4.295
# Tags_Lost to EINS                                  3.2490      0.184     17.683      0.000       2.889       3.609
# Tags_Ringing                                      -0.9345      0.145     -6.453      0.000      -1.218      -0.651
# Tags_Will revert after reading the email           2.8476      0.104     27.382      0.000       2.644       3.051
# Tags_in touch with EINS                            1.3755      0.676      2.036      0.042       0.051       2.700
# Tags_invalid number                               -0.8751      0.428     -2.043      0.041      -1.715      -0.035
# Tags_switched off                                 -0.6000      0.228     -2.636      0.008      -1.046      -0.154
# Last Notable Activity_Email Bounced                1.5200      0.641      2.370      0.018       0.263       2.777
# Last Notable Activity_Had a Phone Conversation     1.5842      1.062      1.491      0.136      -0.498       3.666
# Last Notable Activity_SMS Sent                     2.0267      0.100     20.367      0.000       1.832       2.222
# Last Notable Activity_Unreachable                  1.0817      0.544      1.989      0.047       0.016       2.147
# ==================================================================================================================
#
#                                            features   VIF
# 2                      Last Activity_Email Bounced  1.27
# 13             Last Notable Activity_Email Bounced  1.25
# 4                                        Tags_Busy  1.03
# 1                     Lead Source_Welingak Website  1.03
# 16               Last Notable Activity_Unreachable  1.01
# 7                                Tags_Lost to EINS  1.01
# 11                             Tags_invalid number  1.01
# 14  Last Notable Activity_Had a Phone Conversation  1.01
# 6                    Tags_Interested in Next batch  1.00
# 10                         Tags_in touch with EINS  1.00
# 5                          Tags_Closed by Horizzon  0.33
# 3            Last Activity_Olark Chat Conversation  0.28
# 15                  Last Notable Activity_SMS Sent  0.25
# 0                            Lead Source_Reference  0.20
# 9         Tags_Will revert after reading the email  0.11
# 12                               Tags_switched off  0.04
# 8                                     Tags_Ringing  0.00

# %% [markdown]
# ## Model No 5
#
# Drop Variable "Last Notable Activity_Had a Phone Conversation" -

# %%
# Build the model
cols.remove("Last Notable Activity_Had a Phone Conversation")
X_train_1 = X_train[cols]
X_train_1_sm = sm.add_constant(X_train_1)
Model_5 = sm.GLM(y_train,X_train_1_sm,family=sm.families.Binomial()).fit()
print(Model_5.summary())

# Check VIF -
X = X_train_1
vif = pd.DataFrame()
vif["features"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["VIF"] = round(vif["VIF"] ,2)
vif.sort_values(by = "VIF", ascending = False,inplace = True)
print("\n",vif)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 6372
# Model:                            GLM   Df Residuals:                     6355
# Model Family:                Binomial   Df Model:                           16
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2323.4
# Date:                Tue, 27 Dec 2022   Deviance:                       4646.9
# Time:                        17:29:04   Pearson chi2:                 7.36e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                       -2.3511      0.091    -25.748      0.000      -2.530      -2.172
# Lead Source_Reference                        2.0569      0.244      8.421      0.000       1.578       2.536
# Lead Source_Welingak Website                 5.3854      0.745      7.231      0.000       3.926       6.845
# Last Activity_Email Bounced                 -2.5016      0.403     -6.201      0.000      -3.292      -1.711
# Last Activity_Olark Chat Conversation       -1.8077      0.152    -11.872      0.000      -2.106      -1.509
# Tags_Busy                                    1.2918      0.187      6.903      0.000       0.925       1.659
# Tags_Closed by Horizzon                      2.8912      0.159     18.174      0.000       2.579       3.203
# Tags_Interested in Next batch                2.1606      1.090      1.982      0.047       0.024       4.297
# Tags_Lost to EINS                            3.2485      0.184     17.678      0.000       2.888       3.609
# Tags_Ringing                                -0.9330      0.145     -6.445      0.000      -1.217      -0.649
# Tags_Will revert after reading the email     2.8547      0.104     27.469      0.000       2.651       3.058
# Tags_in touch with EINS                      1.3751      0.675      2.036      0.042       0.051       2.699
# Tags_invalid number                         -0.8737      0.428     -2.040      0.041      -1.713      -0.034
# Tags_switched off                           -0.5985      0.228     -2.630      0.009      -1.045      -0.152
# Last Notable Activity_Email Bounced          1.5209      0.642      2.371      0.018       0.263       2.778
# Last Notable Activity_SMS Sent               2.0228      0.100     20.325      0.000       1.828       2.218
# Last Notable Activity_Unreachable            1.0758      0.544      1.977      0.048       0.009       2.142
# ============================================================================================================
#
#                                      features   VIF
# 2                Last Activity_Email Bounced  1.27
# 13       Last Notable Activity_Email Bounced  1.25
# 1               Lead Source_Welingak Website  1.03
# 4                                  Tags_Busy  1.03
# 7                          Tags_Lost to EINS  1.01
# 11                       Tags_invalid number  1.01
# 15         Last Notable Activity_Unreachable  1.01
# 6              Tags_Interested in Next batch  1.00
# 10                   Tags_in touch with EINS  1.00
# 5                    Tags_Closed by Horizzon  0.33
# 3      Last Activity_Olark Chat Conversation  0.28
# 14            Last Notable Activity_SMS Sent  0.25
# 0                      Lead Source_Reference  0.20
# 9   Tags_Will revert after reading the email  0.11
# 12                         Tags_switched off  0.04
# 8                               Tags_Ringing  0.00

# %% [markdown]
# # Model Evaluation

# %%
# Create the prediction dataframe -
predict_df = pd.DataFrame({"Student_id":y_train.index, "Converted":y_train, "Prob":Model_5.predict(X_train_1_sm)})
predict_df["Predicted"] = predict_df["Prob"].apply(lambda x : 1 if x > 0.5 else 0)
predict_df.head()
# Out:
#       Student_id  Converted      Prob  Predicted
# 7962        7962          0  0.418656          0
# 5520        5520          0  0.257441          0
# 1962        1962          0  0.049753          0
# 1566        1566          1  0.623302          1
# 9170        9170          0  0.086976          0

# %%
# Calculate the Accuracy -
metrics.accuracy_score(predict_df.Converted,predict_df.Predicted)
# Out:
# 0.8389830508474576

# %%
# Finding evaluation parameter -
confusion_matrix = metrics.confusion_matrix(predict_df.Converted,predict_df.Predicted)

# %%
confusion_matrix
# Out:
# array([[3330,  623],
#        [ 403, 2016]])

# %%
TP=confusion_matrix[1,1]
TN=confusion_matrix[0,0]
FN=confusion_matrix[0,1]
FP=confusion_matrix[1,0]

# %%
# Sensitivity =
TP/float(TP+FN)
# Out:
# 0.7639257294429708

# %%
# Specificity =
TN/float(TN + FP)
# Out:
# 0.8920439324939726

# %%
# False Positive Rate of the Model
FP/float(TN+FP)
# Out:
# 0.10795606750602732

# %%
# Positive Predictive Value (Precision) -
TP/float(TP + FP)
# Out:
# 0.8334022323274081

# %%
# Negative Predictive Value -
TN / float(TN + FN)
# Out:
# 0.8423981785985327

# %% [markdown]
# ## Plotting the ROC Curve

# %%
def draw_roc(actual,prob,a,b):
  FPR,TPR,Threshold = metrics.roc_curve(actual,prob
                                        ,drop_intermediate=False)
  auc_score = metrics.roc_auc_score(actual,prob)
  plt.figure(figsize=(a,b))
  plt.plot(FPR,TPR,label = f"ROC Curve (area={round(auc_score,2)})")
  plt.plot([0,1],[0,1],"--k")
  plt.xlim([0.0 , 1.0])
  plt.ylim([0.0 , 1.05])
  plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver operating characteristic example')
  plt.legend(loc="lower right") 
  plt.show()
  return None

# %%
draw_roc(predict_df.Converted,predict_df.Predicted,10,5)

# %% [markdown]
# ## Finding the opitmal cutoff -

# %%
number = [float(x)/10 for x in range(10)]
for i in number:
  predict_df[i] = predict_df["Prob"].map(lambda x:1 if x>i else 0)

# %%
predict_df.head()
# Out:
#       Student_id  Converted      Prob  Predicted  0.0  0.1  0.2  0.3  0.4  \
# 7962        7962          0  0.418656          0    1    1    1    1    1
# 5520        5520          0  0.257441          0    1    1    1    0    0
# 1962        1962          0  0.049753          0    1    0    0    0    0
# 1566        1566          1  0.623302          1    1    1    1    1    1
# 9170        9170          0  0.086976          0    1    0    0    0    0
#
#       0.5  0.6  0.7  0.8  0.9
# 7962    0    0    0    0    0
# 5520    0    0    0    0    0
# 1962    0    0    0    0    0
# 1566    1    1    0    0    0
# 9170    0    0    0    0    0

# %%
# Calculate the accuracy,sensitvity,secificity
cut_off = pd.DataFrame(columns=["prob","acc","sens","spec"])
for i in number :
  cm1 = metrics.confusion_matrix(predict_df.Converted,predict_df[i])
  TP = cm1[1,1]
  TN = cm1[0,0]
  FN = cm1[1,0]
  FP = cm1[0,1]
  acc = (TP+TN)/(TP+TN+FN+FP)
  # metrics.accuracy_score(df_pred.Churn, df_pred[i])
  sens = TP/(TP+FN)
  spec = TN/(TN+FP)
  cut_off.loc[i] = [i,acc,sens,spec]
print(cut_off)
# Out:
#      prob       acc      sens      spec
# 0.0   0.0  0.379630  1.000000  0.000000
# 0.1   0.1  0.763340  0.935924  0.657728
# 0.2   0.2  0.769460  0.933444  0.669112
# 0.3   0.3  0.841965  0.866474  0.826967
# 0.4   0.4  0.842279  0.864407  0.828738
# 0.5   0.5  0.838983  0.833402  0.842398
# 0.6   0.6  0.839297  0.833402  0.842904
# 0.7   0.7  0.795669  0.515502  0.967114
# 0.8   0.8  0.781858  0.446879  0.986845
# 0.9   0.9  0.777307  0.433650  0.987604

# %%
# Plot the curve for acc, sens, spec
cut_off.plot.line(x="prob",y=["acc","sens","spec"])
plt.show()

# %% [markdown]
# - We select 0.5 as the Cut-off

# %% [markdown]
# # Prediction on Test dataset

# %%
# X, y split for test data set -
y_test = test.pop("Converted")
X_test = test

# %%
X_test.head()
# Out:
#       Total Time Spent on Website  Lead Source_Direct Traffic  \
# 3504                          424                           0
# 4050                            0                           0
# 7201                          712                           1
# 1196                          423                           0
# 8219                          247                           1
#
#       Lead Source_Facebook  Lead Source_Google  Lead Source_Live Chat  \
# 3504                     0                   0                      0
# 4050                     0                   0                      0
# 7201                     0                   0                      0
# 1196                     0                   0                      0
# 8219                     0                   0                      0
#
#       Lead Source_NC_EDM  Lead Source_Olark Chat  Lead Source_Organic Search  \
# 3504                   0                       0                           1
# 4050                   0                       0                           0
# 7201                   0                       0                           0
# 1196                   0                       0                           1
# 8219                   0                       0                           0
#
#       Lead Source_Pay per Click Ads  Lead Source_Press_Release  \
# 3504                              0                          0
# 4050                              0                          0
# 7201                              0                          0
# 1196                              0                          0
# 8219                              0                          0
#
#       Lead Source_Reference  Lead Source_Referral Sites  \
# 3504                      0                           0
# 4050                      1                           0
# 7201                      0                           0
# 1196                      0                           0
# 8219                      0                           0
#
#       Lead Source_Social Media  Lead Source_WeLearn  \
# 3504                         0                    0
# 4050                         0                    0
# 7201                         0                    0
# 1196                         0                    0
# 8219                         0                    0
#
#       Lead Source_Welingak Website  Lead Source_bing  Lead Source_blog  \
# 3504                             0                 0                 0
# 4050                             0                 0                 0
# 7201                             0                 0                 0
# 1196                             0                 0                 0
# 8219                             0                 0                 0
#
#       Lead Source_google  Lead Source_testone  Lead Source_welearnblog_Home  \
# 3504                   0                    0                             0
# 4050                   0                    0                             0
# 7201                   0                    0                             0
# 1196                   0                    0                             0
# 8219                   0                    0                             0
#
#       Lead Source_youtubechannel  Last Activity_Converted to Lead  \
# 3504                           0                                0
# 4050                           0                                0
# 7201                           0                                0
# 1196                           0                                0
# 8219                           0                                0
#
#       Last Activity_Email Bounced  Last Activity_Form Submitted on Website  \
# 3504                            0                                        0
# 4050                            0                                        0
# 7201                            0                                        0
# 1196                            0                                        0
# 8219                            0                                        0
#
#       Last Activity_Olark Chat Conversation  \
# 3504                                      0
# 4050                                      0
# 7201                                      0
# 1196                                      0
# 8219                                      0
#
#       Last Activity_View in browser link Clicked  \
# 3504                                           0
# 4050                                           0
# 7201                                           0
# 1196                                           0
# 8219                                           0
#
#       Last Activity_Visited Booth in Tradeshow  \
# 3504                                         0
# 4050                                         0
# 7201                                         0
# 1196                                         0
# 8219                                         0
#
#       Specialization_Business Administration  Specialization_E-Business  \
# 3504                                       1                          0
# 4050                                       1                          0
# 7201                                       0                          0
# 1196                                       0                          0
# 8219                                       0                          0
#
#       Specialization_E-COMMERCE  Specialization_Finance Management  \
# 3504                          0                                  0
# 4050                          0                                  0
# 7201                          0                                  0
# 1196                          0                                  0
# 8219                          0                                  1
#
#       Specialization_Healthcare Management  \
# 3504                                     0
# 4050                                     0
# 7201                                     1
# 1196                                     0
# 8219                                     0
#
#       Specialization_Hospitality Management  \
# 3504                                      0
# 4050                                      0
# 7201                                      0
# 1196                                      0
# 8219                                      0
#
#       Specialization_Human Resource Management  \
# 3504                                         0
# 4050                                         0
# 7201                                         0
# 1196                                         0
# 8219                                         0
#
#       Specialization_IT Projects Management  \
# 3504                                      0
# 4050                                      0
# 7201                                      0
# 1196                                      0
# 8219                                      0
#
#       Specialization_International Business  \
# 3504                                      0
# 4050                                      0
# 7201                                      0
# 1196                                      0
# 8219                                      0
#
#       Specialization_Marketing Management  \
# 3504                                    0
# 4050                                    0
# 7201                                    0
# 1196                                    0
# 8219                                    0
#
#       Specialization_Media and Advertising  \
# 3504                                     0
# 4050                                     0
# 7201                                     0
# 1196                                     0
# 8219                                     0
#
#       Specialization_Operations Management  Specialization_Retail Management  \
# 3504                                     0                                 0
# 4050                                     0                                 0
# 7201                                     0                                 0
# 1196                                     0                                 0
# 8219                                     0                                 0
#
#       Specialization_Rural and Agribusiness  \
# 3504                                      0
# 4050                                      0
# 7201                                      0
# 1196                                      0
# 8219                                      0
#
#       Specialization_Services Excellence  \
# 3504                                   0
# 4050                                   0
# 7201                                   0
# 1196                                   0
# 8219                                   0
#
#       Specialization_Supply Chain Management  \
# 3504                                       0
# 4050                                       0
# 7201                                       0
# 1196                                       0
# 8219                                       0
#
#       Specialization_Travel and Tourism  \
# 3504                                  0
# 4050                                  0
# 7201                                  0
# 1196                                  1
# 8219                                  0
#
#       What is your current occupation_Housewife  \
# 3504                                          0
# 4050                                          0
# 7201                                          0
# 1196                                          0
# 8219                                          0
#
#       What is your current occupation_Other  \
# 3504                                      0
# 4050                                      0
# 7201                                      0
# 1196                                      0
# 8219                                      0
#
#       What is your current occupation_Student  \
# 3504                                        0
# 4050                                        0
# 7201                                        0
# 1196                                        0
# 8219                                        0
#
#       What is your current occupation_Working Professional  Tags_Busy  \
# 3504                                                  0             0
# 4050                                                  0             0
# 7201                                                  0             0
# 1196                                                  0             0
# 8219                                                  0             0
#
#       Tags_Closed by Horizzon  Tags_Diploma holder (Not Eligible)  \
# 3504                        0                                   0
# 4050                        0                                   0
# 7201                        0                                   0
# 1196                        0                                   0
# 8219                        0                                   0
#
#       Tags_Graduation in progress  Tags_In confusion whether part time or DLP  \
# 3504                            0                                           0
# 4050                            0                                           0
# 7201                            0                                           0
# 1196                            0                                           0
# 8219                            0                                           0
#
#       Tags_Interested  in full time MBA  Tags_Interested in Next batch  \
# 3504                                  0                              0
# 4050                                  0                              0
# 7201                                  0                              0
# 1196                                  0                              0
# 8219                                  0                              0
#
#       Tags_Interested in other courses  Tags_Lateral student  \
# 3504                                 0                     0
# 4050                                 0                     0
# 7201                                 0                     0
# 1196                                 0                     0
# 8219                                 0                     0
#
#       Tags_Lost to EINS  Tags_Lost to Others  \
# 3504                  0                    0
# 4050                  0                    0
# 7201                  0                    0
# 1196                  0                    0
# 8219                  1                    0
#
#       Tags_Not doing further education  Tags_Recognition issue (DEC approval)  \
# 3504                                 0                                      0
# 4050                                 0                                      0
# 7201                                 0                                      0
# 1196                                 0                                      0
# 8219                                 0                                      0
#
#       Tags_Ringing  Tags_Shall take in the next coming month  \
# 3504             1                                         0
# 4050             0                                         0
# 7201             0                                         0
# 1196             1                                         0
# 8219             0                                         0
#
#       Tags_Still Thinking  Tags_University not recognized  \
# 3504                    0                               0
# 4050                    0                               0
# 7201                    0                               0
# 1196                    0                               0
# 8219                    0                               0
#
#       Tags_Want to take admission but has financial problems  \
# 3504                                                  0
# 4050                                                  0
# 7201                                                  0
# 1196                                                  0
# 8219                                                  0
#
#       Tags_Will revert after reading the email  Tags_in touch with EINS  \
# 3504                                         0                        0
# 4050                                         1                        0
# 7201                                         0                        0
# 1196                                         0                        0
# 8219                                         0                        0
#
#       Tags_invalid number  Tags_number not provided  Tags_opp hangup  \
# 3504                    0                         0                0
# 4050                    0                         0                0
# 7201                    0                         1                0
# 1196                    0                         0                0
# 8219                    0                         0                0
#
#       Tags_switched off  Tags_wrong number given  \
# 3504                  0                        0
# 4050                  0                        0
# 7201                  0                        0
# 1196                  0                        0
# 8219                  0                        0
#
#       Lead Quality_Low in Relevance  Lead Quality_Might be  \
# 3504                              0                      0
# 4050                              0                      0
# 7201                              0                      1
# 1196                              0                      0
# 8219                              0                      1
#
#       Lead Quality_Not Sure  Lead Quality_Worst  City_Other Cities  \
# 3504                      1                   0                  0
# 4050                      0                   0                  0
# 7201                      0                   0                  0
# 1196                      1                   0                  1
# 8219                      0                   0                  1
#
#       City_Other Cities of Maharashtra  City_Other Metro Cities  \
# 3504                                 0                        0
# 4050                                 0                        0
# 7201                                 0                        0
# 1196                                 0                        0
# 8219                                 0                        0
#
#       City_Thane & Outskirts  City_Tier II Cities  \
# 3504                       0                    0
# 4050                       1                    0
# 7201                       0                    0
# 1196                       0                    0
# 8219                       0                    0
#
#       Last Notable Activity_Email Bounced  \
# 3504                                    0
# 4050                                    0
# 7201                                    0
# 1196                                    0
# 8219                                    0
#
#       Last Notable Activity_Email Link Clicked  \
# 3504                                         0
# 4050                                         0
# 7201                                         0
# 1196                                         0
# 8219                                         0
#
#       Last Notable Activity_Email Marked Spam  \
# 3504                                        0
# 4050                                        0
# 7201                                        0
# 1196                                        0
# 8219                                        0
#
#       Last Notable Activity_Email Received  \
# 3504                                     0
# 4050                                     0
# 7201                                     0
# 1196                                     0
# 8219                                     0
#
#       Last Notable Activity_Form Submitted on Website  \
# 3504                                                0
# 4050                                                0
# 7201                                                0
# 1196                                                0
# 8219                                                0
#
#       Last Notable Activity_Had a Phone Conversation  \
# 3504                                               0
# 4050                                               0
# 7201                                               0
# 1196                                               0
# 8219                                               0
#
#       Last Notable Activity_Modified  \
# 3504                               0
# 4050                               0
# 7201                               0
# 1196                               0
# 8219                               0
#
#       Last Notable Activity_Olark Chat Conversation  \
# 3504                                              0
# 4050                                              0
# 7201                                              0
# 1196                                              0
# 8219                                              0
#
#       Last Notable Activity_Page Visited on Website  \
# 3504                                              0
# 4050                                              0
# 7201                                              0
# 1196                                              0
# 8219                                              1
#
#       Last Notable Activity_Resubscribed to emails  \
# 3504                                             0
# 4050                                             0
# 7201                                             0
# 1196                                             0
# 8219                                             0
#
#       Last Notable Activity_SMS Sent  Last Notable Activity_Unreachable  \
# 3504                               0                                  0
# 4050                               1                                  0
# 7201                               1                                  0
# 1196                               0                                  0
# 8219                               0                                  0
#
#       Last Notable Activity_Unsubscribed  \
# 3504                                   0
# 4050                                   0
# 7201                                   0
# 1196                                   0
# 8219                                   0
#
#       Last Notable Activity_View in browser link Clicked
# 3504                                                  0
# 4050                                                  0
# 7201                                                  0
# 1196                                                  0
# 8219                                                  0

# %%
X_test_sm = sm.add_constant(X_test[cols])

# %%
# Prepare the dataframe of predictions:
df_pred_test = pd.DataFrame({"Student_id":y_test.index,"Converted":y_test,"Prob":Model_5.predict(X_test_sm)})

# Use cut-off of 0.5
df_pred_test["Prediction"] = df_pred_test["Prob"].apply(lambda x:1 if x >= 0.5 else 0)
df_pred_test.head()
# Out:
#       Student_id  Converted      Prob  Prediction
# 3504        3504          0  0.036119           0
# 4050        4050          1  0.989883           1
# 7201        7201          0  0.418656           0
# 1196        1196          0  0.036119           0
# 8219        8219          1  0.710410           1

# %%
# Check the Accuracy -
metrics.accuracy_score(df_pred_test.Converted, df_pred_test.Prediction)
# Out:
# 0.8366898571951666

# %%
# Confusion metrics for test dataset -
confusion_matrix_1 = metrics.confusion_matrix(df_pred_test.Converted,df_pred_test.Prediction)

# %%
confusion_matrix_1
# Out:
# array([[1408,  281],
#        [ 165,  877]])

# %%
TP_1=confusion_matrix_1[1,1]
TN_1=confusion_matrix_1[0,0]
FN_1=confusion_matrix_1[0,1]
FP_1=confusion_matrix_1[1,0]

# %%
# Check the other metrics
print(f"Sensitivity     = {TP_1/(TP_1+FN_1)}")
print(f"Specificity     = {TN_1/(TN_1+FP_1)}")
print(f"Recall          = {TP_1/float(TP_1+FN_1)}")
print(f"Precision       = {TP_1/float(TP_1+FP_1)}")
# Out:
# Sensitivity     = 0.7573402417962003
# Specificity     = 0.8951048951048951
# Recall          = 0.7573402417962003
# Precision       = 0.8416506717850288

# %% [markdown]
# # Interpretation of Model

# %%
# Feature and its importance -
print("------------Feature------------------------------Importance-------")
print(Model_5.params)
# Out:
# ------------Feature------------------------------Importance-------
# const                                      -2.351127
# Lead Source_Reference                       2.056934
# Lead Source_Welingak Website                5.385437
# Last Activity_Email Bounced                -2.501635
# Last Activity_Olark Chat Conversation      -1.807745
# Tags_Busy                                   1.291817
# Tags_Closed by Horizzon                     2.891170
# Tags_Interested in Next batch               2.160611
# Tags_Lost to EINS                           3.248506
# Tags_Ringing                               -0.933022
# Tags_Will revert after reading the email    2.854716
# Tags_in touch with EINS                     1.375077
# Tags_invalid number                        -0.873668
# Tags_switched off                          -0.598527
# Last Notable Activity_Email Bounced         1.520869
# Last Notable Activity_SMS Sent              2.022834
# Last Notable Activity_Unreachable           1.075803
# dtype: float64

# %% [markdown]
# - The final Model contains 16 features
# - The top three important features are -
#
#   1.Lead Source_Welingak Website
#
#   2.Tags_Lost to EINS
#
#   3.Tags_Will revert after reading the email
